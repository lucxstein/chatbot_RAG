# %%
import pandas as pd

# %%
df = pd.read_csv("mundo_transfermarkt_competicoes_brasileirao_serie_a.csv")
df.head()
# Out:
#    ano_campeonato        data  rodada                                estadio  \
# 0            2006  2006-07-12      11     Estádio Governador Magalhães Pinto
# 1            2006  2006-07-12      11              Estádio Orlando Scarpelli
# 2            2006  2006-07-12      11  Estádio Municipal Anacleto Campanella
# 3            2006  2006-07-13      11                         Allianz Parque
# 4            2006  2006-07-13      11            Estádio José do Rego Maciel
#
#   arbitro  publico  publico_max time_mandante time_visitante tecnico_mandante  \
# 0     NaN      NaN          NaN    Fluminense       Flamengo              NaN
# 1     NaN      NaN          NaN      Flamengo    Atlético-PR              NaN
# 2     NaN      NaN          NaN   Corinthians     Santa Cruz              NaN
# 3     NaN      NaN          NaN        Grêmio      Santos FC              NaN
# 4     NaN      NaN          NaN     São Paulo     Fluminense              NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8445 entries, 0 to 8444
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ano_campeonato                  8445 non-null   int64
#  1   data                            8445 non-null   object
#  2   rodada                          8445 non-null   int64
#  3   estadio                         8434 non-null   object
#  4   arbitro                         6735 non-null   object
#  5   publico                         6734 non-null   float64
#  6   publico_max                     4173 non-null   float64
#  7   time_mandante                   8445 non-null   object
#  8   time_visitante                  8445 non-null   object
#  9   tecnico_mandante                6291 non-null   object
#  10  tecnico_visitante               6291 non-null   object
#  11  colocacao_mandante              6735 non-null   float64
# ...

# %%
anos_validos = df.loc[df['escanteios_mandante'].notna(), 'ano_campeonato'].unique()

# %%
anos_validos
# Out:
# array([2024, 2023, 2021, 2022, 2020, 2018, 2019])

# %%
df_filtrado = df[df['ano_campeonato'].between(2020, 2023)]

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1520 entries, 4265 to 6924
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ano_campeonato                  1520 non-null   int64
#  1   data                            1520 non-null   object
#  2   rodada                          1520 non-null   int64
#  3   estadio                         1520 non-null   object
#  4   arbitro                         1520 non-null   object
#  5   publico                         1520 non-null   float64
#  6   publico_max                     1504 non-null   float64
#  7   time_mandante                   1520 non-null   object
#  8   time_visitante                  1520 non-null   object
#  9   tecnico_mandante                1451 non-null   object
#  10  tecnico_visitante               1451 non-null   object
#  11  colocacao_mandante              1520 non-null   float64
# ...

# %%
df_filtrado.to_csv("df_brasileiro.csv", index=False)
